# %%
import pandas as pd
import numpy as np
from datetime import date
from jugaad_data.nse import bhavcopy_save, bhavcopy_fo_save
from jugaad_data.nse import stock_df

# %%
df = stock_df(symbol="SBIN", from_date=date(2023,1,1),
            to_date=date(2023,10,1), series="EQ")

# %%
df
# Out:
#           DATE SERIES    OPEN    HIGH     LOW  PREV. CLOSE     LTP   CLOSE  \
# 0   2023-09-29     EQ  592.85  600.00  591.30       589.95  598.30  598.55
# 1   2023-09-28     EQ  591.25  595.20  588.85       589.75  590.50  589.95
# 2   2023-09-27     EQ  593.45  594.30  588.20       594.40  590.00  589.75
# 3   2023-09-26     EQ  594.00  595.00  591.25       594.05  594.45  594.40
# 4   2023-09-25     EQ  601.50  601.50  590.45       598.15  593.95  594.05
# ..         ...    ...     ...     ...     ...          ...     ...     ...
# 180 2023-01-06     EQ  607.40  607.45  597.00       605.10  601.00  600.65
# 181 2023-01-05     EQ  607.00  611.60  601.95       605.20  605.75  605.10
# 182 2023-01-04     EQ  611.85  614.95  604.00       612.40  605.60  605.20
# 183 2023-01-03     EQ  614.50  616.60  610.00       612.20  612.95  612.40
# 184 2023-01-02     EQ  614.95  619.20  611.20       613.70  612.60  612.20
#
#        VWAP   52W H   52W L    VOLUME         VALUE  NO OF TRADES SYMBOL
# 0    597.22  629.55  499.35  12189735  7.279947e+09        224164   SBIN
# 1    591.37  629.55  499.35  21960816  1.298696e+10        287488   SBIN
# 2    590.74  629.55  499.35   9865347  5.827827e+09        232626   SBIN
# 3    593.80  629.55  499.35   8327427  4.944809e+09        185873   SBIN
# 4    594.79  629.55  499.35   9712784  5.777110e+09        262285   SBIN
# ..      ...     ...     ...       ...           ...           ...    ...
# 180  601.57  629.55  425.00   7972036  4.795747e+09        154179   SBIN
# 181  605.84  629.55  425.00   8241475  4.992982e+09        146571   SBIN
# 182  607.74  629.55  425.00   7011191  4.260969e+09        113548   SBIN
# 183  613.26  629.55  425.00   6818062  4.181258e+09        122799   SBIN
# 184  614.42  629.55  425.00   6726084  4.132615e+09        125418   SBIN
#
# [185 rows x 15 columns]
